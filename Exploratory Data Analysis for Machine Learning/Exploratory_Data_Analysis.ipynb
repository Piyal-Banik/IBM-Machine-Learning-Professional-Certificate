# %% [markdown]
# ## Import the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
dataset = pd.read_csv('weatherAUS.csv')
dataset.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
dataset.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
dataset.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# Humidity3pm    0.006089 -0.508855  0.255755    -0.390243 -0.629130
# Pressure9am   -0.450970 -0.332061 -0.168154    -0.270362  0.041970
# Pressure3pm   -0.461292 -0.427167 -0.126534    -0.293581 -0.019719
# Cloud9am       0.078754 -0.289370  0.198528    -0.183793 -0.675323
# ...

# %%
print('Number of Cities: ' + str(len(dataset['Location'].unique())))
print(dataset['Location'].value_counts())
# Out:
# Number of Cities: 49
# Canberra            3436
# Sydney              3344
# Perth               3193
# Darwin              3193
# Melbourne           3193
# Brisbane            3193
# Adelaide            3193
# Hobart              3193
# Wollongong          3040
# Bendigo             3040
# Cairns              3040
# MountGinini         3040
# Albany              3040
# Albury              3040
# Ballarat            3040
# Townsville          3040
# GoldCoast           3040
# AliceSprings        3040
# Launceston          3040
# MountGambier        3040
# Newcastle           3039
# Penrith             3039
# Tuggeranong         3039
# PerthAirport        3009
# Sale                3009
# NorfolkIsland       3009
# CoffsHarbour        3009
# Dartmoor            3009
# Woomera             3009
# Portland            3009
# MelbourneAirport    3009
# Richmond            3009
# Cobar               3009
# PearceRAAF          3009
# Nuriootpa           3009
# Witchcliffe         3009
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Missing Value

# %%
missing_data = dataset.isnull()

for column in missing_data.columns.values.tolist():
    print(column)
    print(str(np.sum(missing_data[column])) + ' missing values - ' + str(np.sum(missing_data[column]) / 145460 * 100) + " %" )
    print("")
# Out:
# Date
# 0 missing values - 0.0 %
#
# Location
# 0 missing values - 0.0 %
#
# MinTemp
# 1485 missing values - 1.0208992162793895 %
#
# MaxTemp
# 1261 missing values - 0.8669049910628353 %
#
# Rainfall
# 3261 missing values - 2.2418534304963567 %
#
# Evaporation
# 62790 missing values - 43.166506256015396 %
#
# Sunshine
# 69835 missing values - 48.00976213391998 %
#
# WindGustDir
# 10326 missing values - 7.098858792795271 %
#
# WindGustSpeed
# 10263 missing values - 7.055547916953114 %
#
# WindDir9am
# 10566 missing values - 7.263852605527293 %
#
# WindDir3pm
# 4228 missing values - 2.906641000962464 %
#
# WindSpeed9am
# 1767 missing values - 1.214766946239516 %
#
# WindSpeed3pm
# 3062 missing values - 2.105046060772721 %
#
# Humidity9am
# 2654 missing values - 1.8245565791282825 %
#
# Humidity3pm
# 4507 missing values - 3.09844630826344 %
#
# Pressure9am
# 15065 missing values - 10.356799120033 %
#
# Pressure3pm
# 15028 missing values - 10.331362573903478 %
#
# Cloud9am
# ...

# %%
dataset.drop(['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], axis = 1, inplace = True)

# %%
for column in dataset.columns.values.tolist():
    if(dataset[column].dtype == np.float64):
        mean = dataset[column].mean()
        dataset[column].replace(np.NaN, mean, inplace = True)
    else:
        most_common = dataset[column].value_counts().idxmax()
        dataset[column].replace(np.NaN, most_common, inplace = True)

# %% [markdown]
# ### Visualisation

# %%
sns.pairplot(dataset, hue = 'RainTomorrow')
